# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
"""
taska data split
"""
task = "task" + "a"
for i in [100,1000,10000,50000]:
    df_task = pd.read_csv("/public/home/tianhaosu/EPW/PEWfeature/magtype48_01.csv")
    train,test = train_test_split(df_task,test_size=0.1)
    print(len(df_task))
    tmp = train.iloc[:i,1:]
    tmp.to_csv("./"+task+str(i)+".csv",index=None)
# Out:
# 122017
# 122017
# 122017
# 122017

# %%
df_task
# Out:
#         Unnamed: 0    task_id         F1         F2         F3  ...    F46    F47    F48  Unnamed: 0.1  type
# 0                0    mp-9999   1.563342   1.563333   1.563361  ... -230.0 -230.0 -230.0         62986     0
# 1                1    mp-9998 -30.074436 -32.454254 -29.039521  ... -230.0 -230.0 -230.0         49493     0
# 2                2    mp-9996 -15.811006 -17.891333 -14.799325  ... -230.0 -230.0 -230.0         53986     0
# 3                3  mp-999576   1.253167   1.253166   1.253170  ... -230.0 -230.0 -230.0          4972     1
# 4                4  mp-999566   1.253165   1.253165   1.253165  ... -230.0 -230.0 -230.0         19471     1
# ...            ...        ...        ...        ...        ...  ...    ...    ...    ...           ...   ...
# 122012      122012   mp-10000 -18.954845 -21.273918 -17.924058  ... -230.0 -230.0 -230.0          1000     0
# 122013      122013    mp-1000   1.563320   1.563320   1.563320  ... -230.0 -230.0 -230.0         61500     0
# ...

# %%
"""
taskb data split
"""
task = "task" + "b"
for i in [100,1000,10000]:
    df_task = pd.read_csv("/public/home/tianhaosu/EPW/PEWfeature/magtype48_1_1.csv")
    train,test = train_test_split(df_taskb,test_size=0.1)
    #print(len(df_task))
    tmp = train.iloc[:i,1:]
    tmp.to_csv("./"+task+str(i)+".csv",index=None)

# %%
"""
taskc data split
"""
task = "task" + "c"
for i in [100,1000,10000,50000]:
    df_task = pd.read_csv("/public/home/tianhaosu/EPW/PEWfeature/gaptype60_0_1.csv")
    train,test = train_test_split(df_task,test_size=0.1)
    print(len(df_task))
    tmp = train.iloc[:i,1:]
    tmp.to_csv("./"+task+str(i)+".csv",index=None)
# Out:
# 107797
# 107797
# 107797
# 107797

# %%
"""
taskd data split
"""
task = "task" + "d"
for i in [100,1000,10000]:
    df_task = pd.read_csv("/public/home/tianhaosu/EPW/PEWfeature/gaptype48_01.csv")
    train,test = train_test_split(df_task,test_size=0.01)
    print(len(df_task))
    tmp = train.iloc[:i,1:]
    tmp.to_csv("./"+task+str(i)+".csv",index=None)
# Out:
# 28397
# 28397
# 28397

# %%
ls
# Out:
# merge_df.ipynb  task?100.csv    taskb100.csv    taskc100.csv    taskd100.csv
# task?10000.csv  taskb10000.csv  taskc10000.csv  taskd10000.csv
# task?1000.csv   taskb1000.csv   taskc1000.csv   taskd1000.csv
