# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesClassifier as ET
from sklearn.ensemble import RandomForestClassifier as RF
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
from bayes_opt import BayesianOptimization

# %%
df1 = pd.read_csv("./SOAP_pca.csv")
df2 = pd.read_csv("./id_prop.csv",header=None)
df2.columns = ["mpid","target"]
df3 = df2.merge(df1)
df3
# Out:
#              mpid  target          0         1          2          3  \
# 0         mp-1000       1 -59.606070 -2.222345   0.489609  -5.191184
# 1        mp-10009       1 -59.785682 -2.343506   0.371502  -5.625434
# 2      mp-1001012       0 -61.270422 -2.969068   1.455478 -17.202470
# 3      mp-1001015       0 -60.899385 -2.851302   1.179935 -14.368005
# 4      mp-1001019       0 -60.272117 -2.535138   0.571405  -7.821015
# ...           ...     ...        ...       ...        ...        ...
# 28394   mp-999472       1 -59.609710 -2.198701   0.295022  -5.352844
# 28395   mp-999489       1 -59.609824 -2.196534   0.292582  -5.355854
# 28396   mp-999490       1 -59.724362 -2.246240   0.395600  -6.437814
# 28397   mp-999549       1 -60.531688 -2.534115  -1.101073  -2.670066
# 28398     mp-9996       0 -59.317009  2.349315  15.202018  -2.952142
#
#               4          5          6         7  ...         10         11  \
# 0      1.227630  -2.970816  -2.662002  0.186300  ...   2.403600  -1.270349
# 1      1.146875  -3.798791  -3.689483 -0.279115  ...   0.259767  -1.552002
# 2      4.832747  55.378831  33.045282 -0.051031  ...  -6.155442   4.999645
# 3      3.999836  41.295584  24.376978 -0.084863  ...  -4.106245   3.152626
# 4      1.922414  -3.707740  -3.684185  0.669684  ...   7.516197  -8.146756
# ...         ...        ...        ...       ...  ...        ...        ...
# 28394  1.303241  -2.983634  -2.808502  0.095677  ...   2.984254  -2.075680
# 28395  1.304705  -2.984390  -2.810928  0.093336  ...   2.990829  -2.078384
# 28396  1.641576   3.878375   1.508021 -0.021489  ...   1.350064  -0.510907
# 28397 -4.776408  -8.865261 -10.998600 -4.853698  ... -23.903666   2.539219
# 28398 -0.489512   0.521227  -1.823318 -1.559737  ...   5.061334 -30.727685
#
#               12         13         14         15        16         17  \
# 0      -0.106747   1.893640   2.279762  -2.333284  1.711429  -4.506405
# 1       0.383473   2.226940   3.424491  -3.112214  4.471552 -11.564450
# 2       4.327352  -1.747756  -3.502982   0.440742 -2.025736   6.173566
# 3      -0.397903   0.626029   1.038730   1.289337  0.197041   0.236062
# 4      47.650374 -20.153700 -14.736343  11.842976 -7.636946  10.780473
# ...          ...        ...        ...        ...       ...        ...
# 28394   5.667540  -1.470422  -0.175835   0.002228  0.688148  -1.701571
# 28395   5.696284  -1.485144  -0.183879   0.007932  0.681429  -1.692177
# 28396  -0.261734   1.029932   1.486648  -1.575271  1.574218  -2.802049
# 28397   5.025249   0.030571   4.201885  -1.995152  2.272694  -1.704223
# 28398 -20.270181 -10.538799 -16.193523  -6.210702 -9.383639  -6.032817
#
#               18        19
# 0       3.202662 -1.159102
# 1      -2.300174  0.974926
# 2      -4.267763  3.393912
# 3       0.390950 -1.168883
# 4     -10.073821  2.203505
# ...          ...       ...
# 28394   1.381651 -0.164583
# 28395   1.375126 -0.163005
# 28396   2.426587 -0.330006
# 28397  -6.136810 -0.210617
# 28398  -7.450644 -6.772008
#
# [28399 rows x 22 columns]

# %%
X = df3.iloc[:,2:]
y = df3.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

rf = ET(n_estimators=300,criterion="entropy",n_jobs = -1)
print(np.mean(cross_val_score(rf, X, y, cv=10, scoring='roc_auc')))
# Out:
# 0.5827593604882619
